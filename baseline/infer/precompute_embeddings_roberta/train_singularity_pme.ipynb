# %%
# Handle to the workspace
from azure.ai.ml import MLClient

# Authentication package
from azure.identity import DefaultAzureCredential

credential = DefaultAzureCredential()

# Get a handle to the workspace. You can find the info on the workspace tab on ml.azure.com
ml_client = MLClient(
    credential=credential,
    subscription_id="972cf06a-de12-45b1-87f1-3724a2166e79",  # this will look like xxxxxxxx-xxxx-xxxx-xxxx-xxxxxxxxxxxx
    resource_group_name="Ads-Singularity-RG-01",
    workspace_name="ads-singularity-ws01-eastus",
)

# %%
# Verify that the handle works correctly.
# If you get an error here, modify your SUBSCRIPTION, RESOURCE_GROUP, and WS_NAME in the previous cell.
ws = ml_client.workspaces.get("ads-singularity-ws01-eastus")
print(ws.location, ":", ws.resource_group)
# Out:
# eastus : Ads-Singularity-RG-01

# %%
from azure.ai.ml import command, Input

# define the command
command_job = command(   
    experiment_name='hstu-retrieval',
    display_name="9442613_roberta_inference_ads",
    code='.',
    inputs=dict(
        data=dict(
            type="uri_folder",
            path="azureml://datastores/bingads_algo_prod_networkprotection_c08/paths/shares/bingads.hm/local/NativeAds/Relevance/Data/sequential/hstu/v2/ads_vocab_07012025",
            mode="ro_mount",
        ),
    ),
    outputs=dict(
        artifacts=dict(
            type="uri_folder",
            path="azureml://datastores/bingads_algo_prod_networkprotection_c08/paths/shares/bingads.hm/local/NativeAds/Relevance/Data/sequential/hstu/v2/ads_vocab_emb_09302025",
            mode="rw_mount",
        ),
    ),
    command="python3 main.py --data_path ${{inputs.data}} --output_path ${{outputs.artifacts}}",
    environment="hstu:3.2",
    compute="/subscriptions/972cf06a-de12-45b1-87f1-3724a2166e79/resourceGroups/Ads-Singularity-RG-01/providers/Microsoft.MachineLearningServices/virtualclusters/ads-pme-H100",
    resources=dict(
        instance_count=5,
        instance_type="Singularity.ND96r_H100_v5",
        properties=dict(
            singularity=dict(
                interactive="false",
                imageVersion='',
                slaTier="Premium",
                priority="High",
                tensorboardLogDirectory="",
                enableAzmlInt="false"
            )
        )
    ),
    # compute="/subscriptions/972cf06a-de12-45b1-87f1-3724a2166e79/resourceGroups/Ads-Singularity-RG-01/providers/Microsoft.MachineLearningServices/virtualclusters/ads-pretraining",
    # resources=dict(
    #     instance_count=5,
    #     instance_type="Singularity.ND96amrs_A100_v4",
    #     properties=dict(
    #         singularity=dict(
    #             interactive="false",
    #             imageVersion='',
    #             slaTier="Premium",
    #             priority="High",
    #             tensorboardLogDirectory="",
    #             enableAzmlInt="false"
    #         )
    #     )
    # ),    
    distribution=dict(
        type="PyTorch",
        process_count_per_instance=8
    )
)

# submit the command
returned_job = ml_client.jobs.create_or_update(command_job)
# get a URL for the status of the job
returned_job.studio_url
# Out:
# Class AutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteConditionSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseAutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class IntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class ProtectionLevelSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseIntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Uploading precompute_embeddings (0.03 MBs): 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 33954/33954 [00:00<00:00, 1437386.69it/s]
#
#
# pathOnCompute is not a known attribute of class <class 'azure.ai.ml._restclient.v2023_04_01_preview.models._models_py3.UriFolderJobOutput'> and will be ignored
# 'https://ml.azure.com/runs/silly_plate_lgzvfggfk0?wsid=/subscriptions/972cf06a-de12-45b1-87f1-3724a2166e79/resourcegroups/Ads-Singularity-RG-01/workspaces/ads-singularity-ws01-eastus&tid=975f013f-7f24-47e8-a7d3-abc4752bf346'

# %%
from azure.ai.ml import command, Input

# define the command
command_job = command(   
    experiment_name='hstu-retrieval',
    display_name="9442613_roberta_inference_shopping",
    code='.',
    inputs=dict(
        data=dict(
            type="uri_folder",
            path="azureml://datastores/bingads_algo_prod_networkprotection_c08/paths/shares/bingads.hm/local/NativeAds/Relevance/Data/sequential/hstu/v2/shopping_vocab_07012025",
            mode="ro_mount",
        ),
    ),
    outputs=dict(
        artifacts=dict(
            type="uri_folder",
            path="azureml://datastores/bingads_algo_prod_networkprotection_c08/paths/shares/bingads.hm/local/NativeAds/Relevance/Data/sequential/hstu/v2/shopping_vocab_emb_09302025",
            mode="rw_mount",
        ),
    ),
    command="python3 main.py --data_path ${{inputs.data}} --output_path ${{outputs.artifacts}}",
    environment="hstu:3.2",
    compute="/subscriptions/972cf06a-de12-45b1-87f1-3724a2166e79/resourceGroups/Ads-Singularity-RG-01/providers/Microsoft.MachineLearningServices/virtualclusters/ads-pme-H100",
    resources=dict(
        instance_count=4,
        instance_type="Singularity.ND96r_H100_v5",
        properties=dict(
            singularity=dict(
                interactive="false",
                imageVersion='',
                slaTier="Premium",
                priority="High",
                tensorboardLogDirectory="",
                enableAzmlInt="false"
            )
        )
    ),
    # compute="/subscriptions/972cf06a-de12-45b1-87f1-3724a2166e79/resourceGroups/Ads-Singularity-RG-01/providers/Microsoft.MachineLearningServices/virtualclusters/ads-pretraining",
    # resources=dict(
    #     instance_count=5,
    #     instance_type="Singularity.ND96amrs_A100_v4",
    #     properties=dict(
    #         singularity=dict(
    #             interactive="false",
    #             imageVersion='',
    #             slaTier="Premium",
    #             priority="High",
    #             tensorboardLogDirectory="",
    #             enableAzmlInt="false"
    #         )
    #     )
    # ),    
    distribution=dict(
        type="PyTorch",
        process_count_per_instance=8
    )
)

# submit the command
returned_job = ml_client.jobs.create_or_update(command_job)
# get a URL for the status of the job
returned_job.studio_url
# Out:
# Uploading precompute_embeddings (0.03 MBs): 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 34216/34216 [00:00<00:00, 1190153.72it/s]
#
#
# pathOnCompute is not a known attribute of class <class 'azure.ai.ml._restclient.v2023_04_01_preview.models._models_py3.UriFolderJobOutput'> and will be ignored
# 'https://ml.azure.com/runs/hungry_whistle_q2jx89100t?wsid=/subscriptions/972cf06a-de12-45b1-87f1-3724a2166e79/resourcegroups/Ads-Singularity-RG-01/workspaces/ads-singularity-ws01-eastus&tid=975f013f-7f24-47e8-a7d3-abc4752bf346'

# %%
from azure.ai.ml import command, Input

# define the command
command_job = command(   
    experiment_name='hstu-retrieval',
    display_name="9442613_roberta_inference_web_browsing",
    code='.',
    inputs=dict(
        data=dict(
            type="uri_folder",
            path="azureml://datastores/bingads_algo_prod_networkprotection_c08/paths/shares/bingads.hm/local/NativeAds/Relevance/Data/sequential/hstu/v2/web_browsing_vocab_07012025",
            mode="ro_mount",
        ),
    ),
    outputs=dict(
        artifacts=dict(
            type="uri_folder",
            path="azureml://datastores/bingads_algo_prod_networkprotection_c08/paths/shares/bingads.hm/local/NativeAds/Relevance/Data/sequential/hstu/v2/web_browsing_vocab_emb_09302025",
            mode="rw_mount",
        ),
    ),
    command="python3 main.py --data_path ${{inputs.data}} --output_path ${{outputs.artifacts}}",
    environment="hstu:3.2",
    compute="/subscriptions/972cf06a-de12-45b1-87f1-3724a2166e79/resourceGroups/Ads-Singularity-RG-01/providers/Microsoft.MachineLearningServices/virtualclusters/ads-pme-H100",
    resources=dict(
        instance_count=4,
        instance_type="Singularity.ND96r_H100_v5",
        properties=dict(
            singularity=dict(
                interactive="false",
                imageVersion='',
                slaTier="Premium",
                priority="High",
                tensorboardLogDirectory="",
                enableAzmlInt="false"
            )
        )
    ),
    # compute="/subscriptions/972cf06a-de12-45b1-87f1-3724a2166e79/resourceGroups/Ads-Singularity-RG-01/providers/Microsoft.MachineLearningServices/virtualclusters/ads-pretraining",
    # resources=dict(
    #     instance_count=5,
    #     instance_type="Singularity.ND96amrs_A100_v4",
    #     properties=dict(
    #         singularity=dict(
    #             interactive="false",
    #             imageVersion='',
    #             slaTier="Premium",
    #             priority="High",
    #             tensorboardLogDirectory="",
    #             enableAzmlInt="false"
    #         )
    #     )
    # ),    
    distribution=dict(
        type="PyTorch",
        process_count_per_instance=8
    )
)

# submit the command
returned_job = ml_client.jobs.create_or_update(command_job)
# get a URL for the status of the job
returned_job.studio_url
# Out:
# Class AutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteConditionSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseAutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class IntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class ProtectionLevelSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseIntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Uploading precompute_embeddings (0.03 MBs): 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 31910/31910 [00:00<00:00, 2257459.19it/s]
#
#
# pathOnCompute is not a known attribute of class <class 'azure.ai.ml._restclient.v2023_04_01_preview.models._models_py3.UriFolderJobOutput'> and will be ignored
# 'https://ml.azure.com/runs/polite_sail_c2h1znkdvj?wsid=/subscriptions/972cf06a-de12-45b1-87f1-3724a2166e79/resourcegroups/Ads-Singularity-RG-01/workspaces/ads-singularity-ws01-eastus&tid=975f013f-7f24-47e8-a7d3-abc4752bf346'
