# %%
# Handle to the workspace
from azure.ai.ml import MLClient

# Authentication package
from azure.identity import DefaultAzureCredential

credential = DefaultAzureCredential()

# Get a handle to the workspace. You can find the info on the workspace tab on ml.azure.com
ml_client = MLClient(
    credential=credential,
    subscription_id="972cf06a-de12-45b1-87f1-3724a2166e79",  # this will look like xxxxxxxx-xxxx-xxxx-xxxx-xxxxxxxxxxxx
    resource_group_name="Ads-Singularity-RG-01",
    workspace_name="ads-singularity-ws01-eastus",
)

# Verify that the handle works correctly.
# If you get an error here, modify your SUBSCRIPTION, RESOURCE_GROUP, and WS_NAME in the previous cell.
ws = ml_client.workspaces.get("ads-singularity-ws01-eastus")
print(ws.location, ":", ws.resource_group)
# Out:
# Timeout was exceeded in force_flush().
# eastus : Ads-Singularity-RG-01

# %%
from azure.ai.ml import command, Input, Output

# define the command
command_job = command(   
    experiment_name='hstu-retrieval',
    display_name="9803944_eval_ads_inference_8GPU_ta_100m_15k",
    code='./../..',
    inputs=dict(
        data=Input(
            type="uri_folder",
            path="azureml://datastores/bingads_algo_prod_networkprotection_c08/paths/shares/bingads.hm/local/NativeAds/Relevance/Data/sequential/hstu/eval/08062025/sharded_ads_2",
            mode="ro_mount",
        ),
        ckpt=Input(
            type="uri_file",
            path="azureml://datastores/bingads_algo_prod_networkprotection_c08/paths/shares/bingads.hm/local/NativeAds/Relevance/Data/sequential/hstu/v2.5_astrov6/experiments/nifty_tongue_k8b95fw1fp/ckpts/checkpoint_batch0015000.pt",
            mode="ro_mount",
        ), 
        pinsage_ckpt=Input(
            type="uri_folder",
            path="azureml://datastores/bingads_algo_prod_networkprotection_c08/paths/local/users/menghao/pinsage_ckpt",
            mode="ro_mount",
        ), 
        config="configs/ads/eval_07082025_pinsage.gin",
    ),
    outputs=dict(
        out_dir=Output(
            type="uri_folder",
            path="azureml://datastores/bingads_algo_prod_networkprotection_c08/paths/local/users/menghao/c6_eval/ta_100m_15k",
            mode="rw_mount",
        ),
    ),
    # command="sleep infinity",
    command="python3 inference/eval_ads/main.py --data_path ${{inputs.data}} --ckpt_path ${{inputs.ckpt}} --pinsage_ckpt_path ${{inputs.pinsage_ckpt}} --gin_config_file ${{inputs.config}} --output_path ${{outputs.out_dir}}",
    environment="hstu:3.2",
    compute="/subscriptions/972cf06a-de12-45b1-87f1-3724a2166e79/resourceGroups/Ads-Singularity-RG-01/providers/Microsoft.MachineLearningServices/virtualclusters/ads-pme-H100",
    resources=dict(
        instance_count=1,
        instance_type="Singularity.ND96r_H100_v5",
        properties=dict(
            singularity=dict(
                interactive="false",
                imageVersion='',
                slaTier="Premium",
                priority="High",
                tensorboardLogDirectory="",
                enableAzmlInt="false"
            )
        )

    ),   
    distribution=dict(
        type="PyTorch",
        process_count_per_instance=8
    )
)

# submit the command
returned_job = ml_client.jobs.create_or_update(command_job)
# get a URL for the status of the job
returned_job.studio_url
# Out:
# pathOnCompute is not a known attribute of class <class 'azure.ai.ml._restclient.v2023_04_01_preview.models._models_py3.UriFolderJobOutput'> and will be ignored
# 'https://ml.azure.com/runs/teal_pepper_h9cgn189ys?wsid=/subscriptions/972cf06a-de12-45b1-87f1-3724a2166e79/resourcegroups/Ads-Singularity-RG-01/workspaces/ads-singularity-ws01-eastus&tid=975f013f-7f24-47e8-a7d3-abc4752bf346'

# %%
from azure.ai.ml import command, Input, Output

# define the command
command_job = command(   
    experiment_name='hstu-retrieval',
    display_name="9803944_eval_ads_inference_8GPU_astrov6_pinsage_len32_adsweight128_50k",
    code='./../..',
    inputs=dict(
        data=Input(
            type="uri_folder",
            path="azureml://datastores/bingads_algo_prod_networkprotection_c08/paths/shares/bingads.hm/local/NativeAds/Relevance/Data/sequential/hstu/eval/08062025/sharded_ads_2",
            mode="ro_mount",
        ),
        ckpt=Input(
            type="uri_file",
            path="azureml://datastores/bingads_algo_prod_networkprotection_c08/paths/shares/bingads.hm/local/NativeAds/Relevance/Data/sequential/hstu/v2.5_astrov6/experiments/lemon_cartoon_sxwqqbw3fp/ckpts/checkpoint_batch0050000.pt",
            mode="ro_mount",
        ), 
        pinsage_ckpt=Input(
            type="uri_folder",
            path="azureml://datastores/bingads_algo_prod_networkprotection_c08/paths/local/users/menghao/pinsage_ckpt",
            mode="ro_mount",
        ), 
        config="configs/ads/eval_07082025_pinsage.gin",
    ),
    outputs=dict(
        out_dir=Output(
            type="uri_folder",
            path="azureml://datastores/bingads_algo_prod_networkprotection_c08/paths/local/users/menghao/astrov6_pinsage_len32_eval/adsweight128_50k",
            mode="rw_mount",
        ),
    ),
    # command="sleep infinity",
    command="python3 inference/eval_ads/main.py --data_path ${{inputs.data}} --ckpt_path ${{inputs.ckpt}} --pinsage_ckpt_path ${{inputs.pinsage_ckpt}} --gin_config_file ${{inputs.config}} --output_path ${{outputs.out_dir}}",
    environment="hstu:3.2",
    compute="/subscriptions/972cf06a-de12-45b1-87f1-3724a2166e79/resourceGroups/Ads-Singularity-RG-01/providers/Microsoft.MachineLearningServices/virtualclusters/ads-pme-H100",
    resources=dict(
        instance_count=1,
        instance_type="Singularity.ND96r_H100_v5",
        properties=dict(
            singularity=dict(
                interactive="false",
                imageVersion='',
                slaTier="Premium",
                priority="High",
                tensorboardLogDirectory="",
                enableAzmlInt="false"
            )
        )

    ),   
    distribution=dict(
        type="PyTorch",
        process_count_per_instance=8
    )
)

# submit the command
returned_job = ml_client.jobs.create_or_update(command_job)
# get a URL for the status of the job
returned_job.studio_url
# Out:
# pathOnCompute is not a known attribute of class <class 'azure.ai.ml._restclient.v2023_04_01_preview.models._models_py3.UriFolderJobOutput'> and will be ignored
# 'https://ml.azure.com/runs/willing_net_v4396k1wx5?wsid=/subscriptions/972cf06a-de12-45b1-87f1-3724a2166e79/resourcegroups/Ads-Singularity-RG-01/workspaces/ads-singularity-ws01-eastus&tid=975f013f-7f24-47e8-a7d3-abc4752bf346'

# %%
from azure.ai.ml import command, Input, Output

# define the command
command_job = command(   
    experiment_name='hstu-retrieval',
    display_name="9803944_eval_ads_inference_8GPU_astrov6_pinsage_len32_adsweight512_50k",
    code='./../..',
    inputs=dict(
        data=Input(
            type="uri_folder",
            path="azureml://datastores/bingads_algo_prod_networkprotection_c08/paths/shares/bingads.hm/local/NativeAds/Relevance/Data/sequential/hstu/eval/08062025/sharded_ads_2",
            mode="ro_mount",
        ),
        ckpt=Input(
            type="uri_file",
            path="azureml://datastores/bingads_algo_prod_networkprotection_c08/paths/shares/bingads.hm/local/NativeAds/Relevance/Data/sequential/hstu/v2.5_astrov6/experiments/mighty_chayote_gzvwt838sd/ckpts/checkpoint_batch0050000.pt",
            mode="ro_mount",
        ), 
        pinsage_ckpt=Input(
            type="uri_folder",
            path="azureml://datastores/bingads_algo_prod_networkprotection_c08/paths/local/users/menghao/pinsage_ckpt",
            mode="ro_mount",
        ), 
        config="configs/ads/eval_07082025_pinsage.gin",
    ),
    outputs=dict(
        out_dir=Output(
            type="uri_folder",
            path="azureml://datastores/bingads_algo_prod_networkprotection_c08/paths/local/users/menghao/astrov6_pinsage_len32_eval/adsweight512_50k",
            mode="rw_mount",
        ),
    ),
    # command="sleep infinity",
    command="python3 inference/eval_ads/main.py --data_path ${{inputs.data}} --ckpt_path ${{inputs.ckpt}} --pinsage_ckpt_path ${{inputs.pinsage_ckpt}} --gin_config_file ${{inputs.config}} --output_path ${{outputs.out_dir}}",
    environment="hstu:3.2",
    compute="/subscriptions/972cf06a-de12-45b1-87f1-3724a2166e79/resourceGroups/Ads-Singularity-RG-01/providers/Microsoft.MachineLearningServices/virtualclusters/ads-pme-H100",
    resources=dict(
        instance_count=1,
        instance_type="Singularity.ND96r_H100_v5",
        properties=dict(
            singularity=dict(
                interactive="false",
                imageVersion='',
                slaTier="Premium",
                priority="High",
                tensorboardLogDirectory="",
                enableAzmlInt="false"
            )
        )

    ),   
    distribution=dict(
        type="PyTorch",
        process_count_per_instance=8
    )
)

# submit the command
returned_job = ml_client.jobs.create_or_update(command_job)
# get a URL for the status of the job
returned_job.studio_url
# Out:
# pathOnCompute is not a known attribute of class <class 'azure.ai.ml._restclient.v2023_04_01_preview.models._models_py3.UriFolderJobOutput'> and will be ignored
# 'https://ml.azure.com/runs/crimson_drop_24pfdwpjq0?wsid=/subscriptions/972cf06a-de12-45b1-87f1-3724a2166e79/resourcegroups/Ads-Singularity-RG-01/workspaces/ads-singularity-ws01-eastus&tid=975f013f-7f24-47e8-a7d3-abc4752bf346'

# %%
from azure.ai.ml import command, Input, Output

# define the command
command_job = command(   
    experiment_name='hstu-retrieval',
    display_name="9803944_eval_ads_inference_8GPU_astrov6_pinsage_len32_adsonly_50k",
    code='./../..',
    inputs=dict(
        data=Input(
            type="uri_folder",
            path="azureml://datastores/bingads_algo_prod_networkprotection_c08/paths/shares/bingads.hm/local/NativeAds/Relevance/Data/sequential/hstu/eval/08062025/sharded_ads_2",
            mode="ro_mount",
        ),
        ckpt=Input(
            type="uri_file",
            path="azureml://datastores/bingads_algo_prod_networkprotection_c08/paths/shares/bingads.hm/local/NativeAds/Relevance/Data/sequential/hstu/v2.5_astrov6/experiments/shy_fowl_wc3m7k74nd/ckpts/checkpoint_batch0050000.pt",
            mode="ro_mount",
        ), 
        pinsage_ckpt=Input(
            type="uri_folder",
            path="azureml://datastores/bingads_algo_prod_networkprotection_c08/paths/local/users/menghao/pinsage_ckpt",
            mode="ro_mount",
        ), 
        config="configs/ads/eval_07082025_pinsage.gin",
    ),
    outputs=dict(
        out_dir=Output(
            type="uri_folder",
            path="azureml://datastores/bingads_algo_prod_networkprotection_c08/paths/local/users/menghao/astrov6_pinsage_len32_eval/adsonly_50k",
            mode="rw_mount",
        ),
    ),
    # command="sleep infinity",
    command="python3 inference/eval_ads/main.py --data_path ${{inputs.data}} --ckpt_path ${{inputs.ckpt}} --pinsage_ckpt_path ${{inputs.pinsage_ckpt}} --gin_config_file ${{inputs.config}} --output_path ${{outputs.out_dir}}",
    environment="hstu:3.2",
    compute="/subscriptions/972cf06a-de12-45b1-87f1-3724a2166e79/resourceGroups/Ads-Singularity-RG-01/providers/Microsoft.MachineLearningServices/virtualclusters/ads-pme-H100",
    resources=dict(
        instance_count=1,
        instance_type="Singularity.ND96r_H100_v5",
        properties=dict(
            singularity=dict(
                interactive="false",
                imageVersion='',
                slaTier="Premium",
                priority="High",
                tensorboardLogDirectory="",
                enableAzmlInt="false"
            )
        )

    ),   
    distribution=dict(
        type="PyTorch",
        process_count_per_instance=8
    )
)

# submit the command
returned_job = ml_client.jobs.create_or_update(command_job)
# get a URL for the status of the job
returned_job.studio_url
# Out:
# pathOnCompute is not a known attribute of class <class 'azure.ai.ml._restclient.v2023_04_01_preview.models._models_py3.UriFolderJobOutput'> and will be ignored
# 'https://ml.azure.com/runs/gifted_brake_fgszjh8l75?wsid=/subscriptions/972cf06a-de12-45b1-87f1-3724a2166e79/resourcegroups/Ads-Singularity-RG-01/workspaces/ads-singularity-ws01-eastus&tid=975f013f-7f24-47e8-a7d3-abc4752bf346'

# %%
from azure.ai.ml import command, Input, Output

# define the command
command_job = command(   
    experiment_name='hstu-retrieval',
    display_name="9803944_eval_ads_inference_8GPU_astrov6_pinsage_len32_last_ad_only_50k",
    code='./../..',
    inputs=dict(
        data=Input(
            type="uri_folder",
            path="azureml://datastores/bingads_algo_prod_networkprotection_c08/paths/shares/bingads.hm/local/NativeAds/Relevance/Data/sequential/hstu/eval/08062025/sharded_ads_2",
            mode="ro_mount",
        ),
        ckpt=Input(
            type="uri_file",
            path="azureml://datastores/bingads_algo_prod_networkprotection_c08/paths/shares/bingads.hm/local/NativeAds/Relevance/Data/sequential/hstu/v2.5_astrov6/experiments/magenta_stem_5k923nymp3/ckpts/checkpoint_batch0050000.pt",
            mode="ro_mount",
        ), 
        pinsage_ckpt=Input(
            type="uri_folder",
            path="azureml://datastores/bingads_algo_prod_networkprotection_c08/paths/local/users/menghao/pinsage_ckpt",
            mode="ro_mount",
        ), 
        config="configs/ads/eval_07082025_pinsage.gin",
    ),
    outputs=dict(
        out_dir=Output(
            type="uri_folder",
            path="azureml://datastores/bingads_algo_prod_networkprotection_c08/paths/local/users/menghao/astrov6_pinsage_len32_eval/last_ad_only_50k",
            mode="rw_mount",
        ),
    ),
    # command="sleep infinity",
    command="python3 inference/eval_ads/main.py --data_path ${{inputs.data}} --ckpt_path ${{inputs.ckpt}} --pinsage_ckpt_path ${{inputs.pinsage_ckpt}} --gin_config_file ${{inputs.config}} --output_path ${{outputs.out_dir}}",
    environment="hstu:3.2",
    compute="/subscriptions/972cf06a-de12-45b1-87f1-3724a2166e79/resourceGroups/Ads-Singularity-RG-01/providers/Microsoft.MachineLearningServices/virtualclusters/ads-pme-H100",
    resources=dict(
        instance_count=1,
        instance_type="Singularity.ND96r_H100_v5",
        properties=dict(
            singularity=dict(
                interactive="false",
                imageVersion='',
                slaTier="Premium",
                priority="High",
                tensorboardLogDirectory="",
                enableAzmlInt="false"
            )
        )

    ),   
    distribution=dict(
        type="PyTorch",
        process_count_per_instance=8
    )
)

# submit the command
returned_job = ml_client.jobs.create_or_update(command_job)
# get a URL for the status of the job
returned_job.studio_url
# Out:
# pathOnCompute is not a known attribute of class <class 'azure.ai.ml._restclient.v2023_04_01_preview.models._models_py3.UriFolderJobOutput'> and will be ignored
# 'https://ml.azure.com/runs/lemon_brush_tywh8nqglw?wsid=/subscriptions/972cf06a-de12-45b1-87f1-3724a2166e79/resourcegroups/Ads-Singularity-RG-01/workspaces/ads-singularity-ws01-eastus&tid=975f013f-7f24-47e8-a7d3-abc4752bf346'

# %%
from azure.ai.ml import command, Input, Output

# define the command
command_job = command(   
    experiment_name='hstu-retrieval',
    display_name="9803944_eval_ads_inference_8GPU_astrov6_pinsage_len32_last_ad_only_50k_backup",
    code='./../..',
    inputs=dict(
        data=Input(
            type="uri_folder",
            path="azureml://datastores/bingads_algo_prod_networkprotection_c08/paths/shares/bingads.hm/local/NativeAds/Relevance/Data/sequential/hstu/eval/08062025/sharded_ads_2",
            mode="ro_mount",
        ),
        ckpt=Input(
            type="uri_file",
            path="azureml://datastores/bingads_algo_prod_networkprotection_c08/paths/shares/bingads.hm/local/NativeAds/Relevance/Data/sequential/hstu/v2.5_astrov6/experiments/maroon_whale_cpffq23lrc/ckpts/checkpoint_batch0050000.pt",
            mode="ro_mount",
        ), 
        pinsage_ckpt=Input(
            type="uri_folder",
            path="azureml://datastores/bingads_algo_prod_networkprotection_c08/paths/local/users/menghao/pinsage_ckpt",
            mode="ro_mount",
        ), 
        config="configs/ads/eval_07082025_pinsage.gin",
    ),
    outputs=dict(
        out_dir=Output(
            type="uri_folder",
            path="azureml://datastores/bingads_algo_prod_networkprotection_c08/paths/local/users/menghao/astrov6_pinsage_len32_eval/last_ad_only_50k_backup",
            mode="rw_mount",
        ),
    ),
    # command="sleep infinity",
    command="python3 inference/eval_ads/main.py --data_path ${{inputs.data}} --ckpt_path ${{inputs.ckpt}} --pinsage_ckpt_path ${{inputs.pinsage_ckpt}} --gin_config_file ${{inputs.config}} --output_path ${{outputs.out_dir}}",
    environment="hstu:3.2",
    compute="/subscriptions/972cf06a-de12-45b1-87f1-3724a2166e79/resourceGroups/Ads-Singularity-RG-01/providers/Microsoft.MachineLearningServices/virtualclusters/ads-pme-H100",
    resources=dict(
        instance_count=1,
        instance_type="Singularity.ND96r_H100_v5",
        properties=dict(
            singularity=dict(
                interactive="false",
                imageVersion='',
                slaTier="Premium",
                priority="High",
                tensorboardLogDirectory="",
                enableAzmlInt="false"
            )
        )

    ),   
    distribution=dict(
        type="PyTorch",
        process_count_per_instance=8
    )
)

# submit the command
returned_job = ml_client.jobs.create_or_update(command_job)
# get a URL for the status of the job
returned_job.studio_url
# Out:
# Class AutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class AutoDeleteConditionSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseAutoDeleteSettingSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class IntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class ProtectionLevelSchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class BaseIntellectualPropertySchema: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# pathOnCompute is not a known attribute of class <class 'azure.ai.ml._restclient.v2023_04_01_preview.models._models_py3.UriFolderJobOutput'> and will be ignored
# 'https://ml.azure.com/runs/heroic_window_tp00nr6k3v?wsid=/subscriptions/972cf06a-de12-45b1-87f1-3724a2166e79/resourcegroups/Ads-Singularity-RG-01/workspaces/ads-singularity-ws01-eastus&tid=975f013f-7f24-47e8-a7d3-abc4752bf346'

# %% [markdown]
# ## Register Component

# %%
from azure.ai.ml.entities import CommandComponent, PipelineComponent

component_inputs = {}
for k, v in command_job.inputs.items():
    if v.type=='string':
        component_inputs[k] = Input(type="string", default=v._original_data)
    else:
        component_inputs[k] = Input(type=v.type)
print(component_inputs)

component = CommandComponent(
    name="inference_eval_ads",
    version="4.3",
    code=command_job.code,
    command=command_job.command,
    environment=command_job.environment,
    inputs=component_inputs,
    outputs={k: Output(type=v.type) for k, v in command_job.outputs.items()},
    resources=command_job.resources,
    distribution=command_job.distribution
)

ml_client.components.create_or_update(component)
# Out:
# {'data': {'type': 'uri_folder'}, 'ckpt': {'type': 'uri_file'}, 'config': {'type': 'string', 'default': 'configs/ads/eval_07082025_semantic_next_event_prediction.gin'}}
# Uploading hstu_retrieval (0.49 MBs): 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 493731/493731 [00:00<00:00, 1858518.46it/s]
# CommandComponent({'latest_version': None, 'intellectual_property': None, 'auto_increment_version': False, 'source': 'REMOTE.WORKSPACE.COMPONENT', 'is_anonymous': False, 'auto_delete_setting': None, 'name': 'inference_eval_ads', 'description': None, 'tags': {}, 'properties': {}, 'print_as_yaml': False, 'id': '/subscriptions/972cf06a-de12-45b1-87f1-3724a2166e79/resourceGroups/Ads-Singularity-RG-01/providers/Microsoft.MachineLearningServices/workspaces/ads-singularity-ws01-eastus/components/inference_eval_ads/versions/4.3', 'Resource__source_path': None, 'base_path': '/home/azureuser/localfiles/large-rec-model/src/hstu_retrieval/inference/eval_ads', 'creation_context': <azure.ai.ml._restclient.v2024_01_01_preview.models._models_py3.SystemData object at 0x724af8b56f20>, 'serialize': <msrest.serialization.Serializer object at 0x724af6187c70>, 'command': 'python3 inference/eval_ads/main.py --data_path ${{inputs.data}} --ckpt_path ${{inputs.ckpt}} --gin_config_file ${{inputs.config}} --output_path ${{outputs.out_dir}}', 'code': '/subscriptions/972cf06a-de12-45b1-87f1-3724a2166e79/resourceGroups/Ads-Singularity-RG-01/providers/Microsoft.MachineLearningServices/workspaces/ads-singularity-ws01-eastus/codes/aa50ace4-cd19-4166-b81e-8b44c1f32567/versions/1', 'environment_variables': None, 'environment': '/subscriptions/972cf06a-de12-45b1-87f1-3724a2166e79/resourceGroups/Ads-Singularity-RG-01/providers/Microsoft.MachineLearningServices/workspaces/ads-singularity-ws01-eastus/environments/hstu/versions/3.2', 'distribution': <azure.ai.ml.entities._job.distribution.PyTorchDistribution object at 0x724af6186ad0>, 'resources': {'instance_count': 1}, 'queue_settings': None, 'version': '4.3', 'schema': None, 'type': 'command', 'display_name': None, 'is_deterministic': True, 'inputs': {'data': {'type': 'uri_folder', 'optional': False}, 'ckpt': {'type': 'uri_file', 'optional': False}, 'config': {'type': 'string', 'default': 'configs/ads/eval_07082025_semantic_next_event_prediction.gin', 'optional': False}}, 'outputs': {'out_dir': {'type': 'uri_folder'}}, 'yaml_str': None, 'other_parameter': {}, 'additional_includes': []})

# %%
print(dict(command_job.resources) | dict(command_job.resources.properties))
# Out:
# {'locations': None, 'instance_count': 1, 'instance_type': 'Singularity.ND96r_H100_v5', 'shm_size': None, 'max_instance_count': None, 'docker_args': None, 'singularity': {'interactive': 'false', 'imageVersion': '', 'slaTier': 'Premium', 'priority': 'High', 'tensorboardLogDirectory': '', 'enableAzmlInt': 'false'}}
